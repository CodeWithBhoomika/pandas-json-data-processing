# %%
import pandas as pd
df = pd.read_json("input_data.json")
print("Original DataFrame:")
print(df)
df["processed_flag"] = True
df.to_json("processed_data.json", orient="records", indent=4)
print("\nProcessed data saved to processed_data.json")
# Out:
# Original DataFrame:
#    student_id          name  gender               department  year  marks  \
# 0         101  Aarav Sharma    Male         Computer Science     2     85
# 1         102   Priya Reddy  Female   Information Technology     3     78
# 2         103   Karthik Rao    Male             Data Science     1     92
# 3         104   Sneha Patel  Female         Computer Science     4     88
# 4         105   Rohit Verma    Male  Artificial Intelligence     2     74
#
#                       email
# 0  aarav.sharma@example.com
# 1   priya.reddy@example.com
# 2   karthik.rao@example.com
# 3   sneha.patel@example.com
# 4   rohit.verma@example.com
#
# Processed data saved to processed_data.json
